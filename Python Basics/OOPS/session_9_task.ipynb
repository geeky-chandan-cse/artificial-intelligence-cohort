# %% [markdown]
# ### `Problem-1:` Class inheritence
#
# Create a **Bus** child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
class Vehicle:
    def __init__(self, seating_capacity) -> None:
        self.seating_capacity = seating_capacity
    
    def fare(self):
        return self.seating_capacity * 100

class Bus(Vehicle):
    BUS_MAINTENANCE_PERCENTAGE_ON_TOTAL_FARE = 10
    def fare(self):
        current_fare = super().fare()
        bus_maintenance_charge = (current_fare * Bus.BUS_MAINTENANCE_PERCENTAGE_ON_TOTAL_FARE) / 100
        total_bus_fare = current_fare + bus_maintenance_charge
        return f"Total bus fare is : {total_bus_fare}"

bus_instance = Bus(50)
total_fare = bus_instance.fare()
print(total_fare)
# Out:
# Total bus fare is : 5500.0

# %% [markdown]
# ### `Problem-2:` Class Inheritence
#
# Create a Bus class that inherits from the Vehicle class. Give the capacity argument of *Bus.seating_capacity()* a default value of 50.
#
# Use the following code for your parent Vehicle class.

# %%
class Vehicle:
    def __init__(self, seating_capacity) -> None:
        self.seating_capacity = seating_capacity
    
    def fare(self):
        return self.seating_capacity * 100


class Bus(Vehicle):
    BUS_MAINTENANCE_PERCENTAGE_ON_TOTAL_FARE = 10
    def __init__(self, seating_capacity = 50):
        super().__init__(seating_capacity)
    
    def fare(self):
        current_fare = super().fare()
        bus_maintenance_charge = (current_fare * Bus.BUS_MAINTENANCE_PERCENTAGE_ON_TOTAL_FARE) / 100
        total_bus_fare = current_fare + bus_maintenance_charge
        return f"Total bus fare is : {total_bus_fare}"

bus_instance = Bus(50)
total_fare = bus_instance.fare()
print(total_fare)
# Out:
# Total bus fare is : 5500.0

# %% [markdown]
# ### `Problem-3:` Write a program that has a class Point. Define another class Location which has two objects (Location & Destination) of class Point. Also define a function in Location that prints the reflection of Destination on the x axis.

# %%
class Point:
    def __init__(self, x_cordinate, y_cordinate) -> None:
        self.x_cordinate = x_cordinate
        self.y_cordinate = y_cordinate

class Location():
    def __init__(self, x1, y1, x2, y2) -> None:
        self.location = Point(x1, y1)
        self.destination = Point(x2, y2)

    def get_reflaction_on_x_axis(self):
        self.destination.y_cordinate = - self.destination.y_cordinate
        print(f"Reflection of Destination on x-axis: ({self.destination.x_cordinate}, {self.destination.y_cordinate})")

# %%
# Test Case 1: Basic Reflection
print("=" * 50)
print("Test Case 1: Basic Reflection")
print("=" * 50)
loc1 = Location(2, 3, 5, 7)
print(f"Location Point: (2, 3)")
print(f"Destination Point: (5, 7)")
loc1.get_reflaction_on_x_axis()
print()

# Test Case 2: Negative Y-Coordinate
print("=" * 50)
print("Test Case 2: Negative Y-Coordinate")
print("=" * 50)
loc2 = Location(1, 1, 4, -5)
print(f"Location Point: (1, 1)")
print(f"Destination Point: (4, -5)")
loc2.get_reflaction_on_x_axis()
print()

# Test Case 3: Zero Y-Coordinate
print("=" * 50)
print("Test Case 3: Zero Y-Coordinate")
print("=" * 50)
loc3 = Location(0, 0, 3, 0)
print(f"Location Point: (0, 0)")
print(f"Destination Point: (3, 0)")
loc3.get_reflaction_on_x_axis()
print()

# Test Case 4: Large Values
print("=" * 50)
print("Test Case 4: Large Values")
print("=" * 50)
loc4 = Location(100, 200, 500, 1000)
print(f"Location Point: (100, 200)")
print(f"Destination Point: (500, 1000)")
loc4.get_reflaction_on_x_axis()
print()

# Test Case 5: Negative Coordinates
print("=" * 50)
print("Test Case 5: Negative Coordinates")
print("=" * 50)
loc5 = Location(-5, -10, -3, -8)
print(f"Location Point: (-5, -10)")
print(f"Destination Point: (-3, -8)")
loc5.get_reflaction_on_x_axis()
# Out:
# ...
# Test Case 1: Basic Reflection
# ...
# Location Point: (2, 3)
# Destination Point: (5, 7)
# Reflection of Destination on x-axis: (5, -7)
#
# ...
# Test Case 2: Negative Y-Coordinate
# ...
# Location Point: (1, 1)
# Destination Point: (4, -5)
# Reflection of Destination on x-axis: (4, 5)
#
# ...
# Test Case 3: Zero Y-Coordinate
# ...
# Location Point: (0, 0)
# Destination Point: (3, 0)
# Reflection of Destination on x-axis: (3, 0)
#
# ...
# Test Case 4: Large Values
# ...
# Location Point: (100, 200)
# Destination Point: (500, 1000)
# Reflection of Destination on x-axis: (500, -1000)
#
# ...
# Test Case 5: Negative Coordinates
# ...
# Location Point: (-5, -10)
# Destination Point: (-3, -8)
# Reflection of Destination on x-axis: (-3, 8)

# %% [markdown]
# ### `Problem-4:` Write a program that has an abstract class Polygon. Derive two classes Rectangle and Triamgle from Polygon and write methods to get the details of their dimensions and hence calculate the area.

# %%
from abc import ABC, abstractmethod
import math

class Polygon(ABC):
    @abstractmethod
    def get_dimensions(self):
        pass

    @abstractmethod
    def area(self):
        pass

class Rectangle(Polygon):
    def __init__(self, l, b) -> None:
        self.length = l
        self.breadth = b
    
    def get_dimensions(self):
        print(f"Length : {self.length}, Breadth : {self.breadth}")
    
    def area(self):
        area_value = self.length * self.breadth
        print("Area of rectangle : ", area_value)
        return area_value



class Triangle(Polygon):
    def __init__(self, edge1, edge2, edge3) -> None:
        self.edge1 = edge1
        self.edge2 = edge2
        self.edge3 = edge3
    
    def get_dimensions(self):
        print(f"Edge 1: {self.edge1}, Edge 2: {self.edge2}, Edge 3: {self.edge3}")
    
    def area(self):
        # Calculate semi-perimeter
        s = (self.edge1 + self.edge2 + self.edge3) / 2
        # Apply Heron's Formula
        area_value = math.sqrt(s * (s - self.edge1) * (s - self.edge2) * (s - self.edge3))
        print("Area of triangle : ", area_value)
        return area_value

# Example usage:
print("=" * 50)
print("Rectangle Example")
print("=" * 50)
rect = Rectangle(5, 4)
rect.get_dimensions()
rect.area()

print("\n" + "=" * 50)
print("Triangle Example")
print("=" * 50)
tri = Triangle(3, 4, 5)
tri.get_dimensions()
tri.area()

# Example usage:
print("=" * 50)
print("Rectangle Example")
print("=" * 50)
rect = Rectangle(5, 4)
rect.get_dimensions()
rect.area()

print("\n" + "=" * 50)
print("Triangle Example")
print("=" * 50)
tri = Triangle(3, 4, 5)
tri.get_dimensions()
tri.area()
# Out:
# ...
# Rectangle Example
# ...
# Length : 5, Breadth : 4
# Area of rectangle :  20
#
# ...
# Triangle Example
# ...
# Edge 1: 3, Edge 2: 4, Edge 3: 5
# Area of triangle :  6.0
# ...
# Rectangle Example
# ...
# Length : 5, Breadth : 4
# Area of rectangle :  20
#
# ...
# Triangle Example
# ...
# Edge 1: 3, Edge 2: 4, Edge 3: 5
# Area of triangle :  6.0
# 6.0

# %% [markdown]
# ### `Problem-5:` Write a program with class Bill. The users have the option to pay the bill either by cheque or by cash. Use the inheritance to model this situation.

# %%
    
class Cheque:
    def __init__(self, billing_amount):
        self.billing_amount = billing_amount
        print("Pay by cheque")


class Cash:
    def __init__(self, billing_amount):
        print("Pay by cash")
        self.billing_amount = billing_amount

class Bill(Cash, Cheque):
    def __init__(self, billing_amount, billing_method="cash"):
        if billing_method == "cash":
            super().__init__(billing_amount)

# %% [markdown]
# ###`Q-6:` FlexibleDict
# As of now we are accessing values from dictionary with exact keys. Now we want to amend accessing values functionality. if a dict have key `1` (int) the even if we try to access values by giving `'1'` (1 as str) as key, we should get the same result and vice versa.
#
# Write a class `FlexibleDict` upon builtin `dict` class with above required functionality.
#
# Hint- `dict[key] => dict.__getitem__(key)`

# %% [markdown]
# Ex.
# ```
# fd = FlexibleDict()
# fd['a'] = 100
# print(fd['a']) # Like regular dict
#
# fd[5] = 500
# print(fd[5]) # Like regular dict
#
# fd[1] = 100
# print(fd['1']) # actual Key is int but still trying to access through str key.
# fd['1'] = 100
# print(fd[1])
#
# ```
# `Output:`
# ```
# 100
# 500
# 100
# 100
#
# ```

# %%
class FlexibleDict(dict):

    def noramalize_key(self, key):
        """ Normalizes key to str, doesn't care if given key is str or int """
        try:
            # convert to int to check if it's a number
            int_value = int(key)
            return str(int_value)
        except (ValueError, TypeError):
            # If not number return as it is
            return key
        
    def __setitem__(self, key, value):
        """ Override to normalize keys when setting value"""
        noramalized_key = self.noramalize_key(key)
        super().__setitem__(noramalized_key, value)
    
    def __getitem__(self, key):
        """ Override to normalize keys when getting value"""
        noramalized_key = self.noramalize_key(key)
        if self.__contains__(noramalized_key):
            return super().__getitem__(noramalized_key)
        else:
            return None
    
    def __contains__(self, key):
        """ Override to normalize keys when checking existence of a key """
        noramalized_key = self.noramalize_key(key)
        return super().__contains__(noramalized_key)


fd = FlexibleDict()
fd['a'] = 100
print(fd['a']) # Like regular dict

fd[5] = 500
print(fd[5]) # Like regular dict

fd[1] = 100
print(fd['1']) # actual Key is int but still trying to access through str key.
fd['1'] = 100
print(fd[1])

er = fd['ese']
print(er)
# Out:
# 100
# 500
# 100
# 100
# None
